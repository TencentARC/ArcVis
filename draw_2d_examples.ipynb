# %% [markdown]
# # Setup your project folder

# %%
# %cd /path_to/ArcVis
# Out:
# /path_to/ArcVis

# %%
import numpy as np

from plot_2d import draw_2d_components

# %% [markdown]
# # example pts and lines

# %%
pts_x = np.linspace(0, 30, 30)
pts_y = np.random.rand(30) * 5.0
points = [pts_x, pts_y]  # This represents a group of points
lines = [pts_x, pts_y]  # This represents a single lines with 30 pts
lines2 = [pts_x, pts_y + 5.0]

# %%
draw_2d_components(
    points=[points],
    point_size=20,
    lines=[lines, lines2],
    legends=['xy', 'xy2'],
    xlabel='pos',
    ylabel='val',
    title='example 2d'
)
